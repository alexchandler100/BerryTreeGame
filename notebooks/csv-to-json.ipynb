# %%
# load inventory_items as dataframe
import csv,json, os
import pandas as pd
os.chdir('/Users/alexchandler/BerryTreeGame') #change to python script directory
df = pd.read_csv('data/csv-files/inventory_items.csv', dtype='object')  
df
# Out:
#                     name randomEncounterRewards  \
# 0  Andy Capp's Hot Fries                    0.5
# 1         Labatt Max Ice                    0.2
# 2               Gatorade                    0.4
# 3                Monster                    0.4
# 4                  Hamms                    0.4
# 5          Larry Special                    0.2
# 6                 Liquor                    0.6
# 7                   Wine                    0.6
# 8        Protein Monster                    0.6
#
#                           itemEffects all_usable_items_icons numberOwned   sp  \
# 0                      SP Max, HP +10          andycappsIcon           0  max
# 1                      HP +60, SP +15             maxiceIcon           0   15
# 2                 HP +60, stamina max           gatoradeIcon           0    0
# 3        SP +10, cure status ailments            monsterIcon           0   10
# 4                        HP +20 SP +5              hammsIcon           2    5
# 5                      HP max, SP max       larrySpecialIcon           0  max
# 6                              SP Max             liquorIcon           0  max
# 7   Attack +20% (3 turns) -20 stamina               wineIcon           1    0
# 8  Defense +40% (3 turns) +20 stamina     proteinmonsterIcon           1    0
#
#     hp stamina status_ailments attack_up defense_up value
# 0   10       0               0         0          0     1
# 1   60       0               0         0          0     2
# 2   60     max               0         0          0     1
# 3    0       0        cure all         0          0     1
# 4   20       0               0         0          0     1
# 5  max       0               0         0          0    15
# 6    0       0               0         0          0     2
# 7   -5     -20               0       0.2          0     3
# 8    5      20               0         0        0.4     3

# %%
#saves the inventory_items df in json format to 'data/json-files/inventory_items.json'
result = df.to_json(orient = "index")
parsed = json.loads(result)
jsonFilePath='data/json-files/inventory_items.json'
with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
    jsonf.write(json.dumps(parsed, indent=4))
print('saved to '+jsonFilePath)
# Out:
# saved to data/json-files/inventory_items.json

# %%
import csv,json, os
import pandas as pd
os.chdir('/Users/alexchandler/BerryTreeGame') #change to python script directory
df = pd.read_csv('data/csv-files/character-stats.csv', dtype='object')  
df
# Out:
#       name battleScale overworldScale  \
# 0      Mac        0.77           0.77
# 1    Jimmy        0.67           0.13
# 2       Al         0.7          0.175
# 3  Bennett        0.56           0.14
#
#                              sizeAndOffset                  special  \
# 0  {"size": [70, 90], "offset": [60, 105]}  ["Muay Thai Combo (3)"]
# 1  {"size": [64, 64], "offset": [60, 100]}     ["Double Smack (4)"]
# 2   {"size": [64, 128],"offset": [60, 64]}    ["Blast Errbody (5)"]
# 3   {"size": [64, 64],"offset": [60, 100]}      ["Dirty Combo (7)"]
#
#   bleedProof blindProof neverMiss defendOn blind  ... level damage attackUp  \
# 0      false      false     false    false     0  ...     1     35        1
# 1      false      false     false    false     0  ...     1     25        1
# 2      false      false     false    false     0  ...     1     40        1
# 3      false      false     false    false     0  ...     1     45        1
#
#   defenseUp                       skillDialogue playerColors          upper  \
# 0         1  {"3": false,"5": false,"7": false}       0e7d4e   Camo T-Shirt
# 1         1  {"3": false,"5": false,"7": false}       0d2175     Blue Shirt
# 2         1  {"3": false,"5": false,"7": false}       be2016      Red Shirt
# 3         1  {"3": false,"5": false,"7": false}       fa7800  Running Shirt
#
#             lower accessory assessory2
# 0           Jeans       NaN        NaN
# 1       Snowpants       NaN        NaN
# 2  Red Sweatpants       NaN        NaN
# 3  Running Shorts       NaN        NaN
#
# [4 rows x 28 columns]

# %%
#saves the character-stats df in json format to 'data/json-files/inventory_items.json'
result = df.to_json(orient = "index")
parsed = json.loads(result)
jsonFilePath='data/json-files/character-stats.json'
with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
    jsonf.write(json.dumps(parsed, indent=4))
print('saved to '+jsonFilePath)
# Out:
# saved to data/json-files/character-stats.json

# %%
import csv,json, os
import pandas as pd
os.chdir('/Users/alexchandler/BerryTreeGame') #change to python script directory
df = pd.read_csv('data/csv-files/equipment.csv', dtype='object')  
df
# Out:
#                name           type randomEncounterRewards def  \
# 0      Camo T-Shirt      Mac_upper                      0   2
# 1             Jeans      Mac_lower                      0   1
# 2        Blue Shirt    Jimmy_upper                      0   3
# 3         Snowpants    Jimmy_lower                      0   1
# 4         Red Shirt       Al_upper                      0   3
# 5    Red Sweatpants       Al_lower                      0   2
# 6     Running Shirt  Bennett_upper                      0   5
# 7    Running Shorts  Bennett_lower                      0   3
# 8        Camo Hoody      Mac_upper                    0.2  20
# 9        Camo Pants      Mac_lower                    0.2  10
# 10       Fubu Shirt       Al_upper                    0.2  12
# 11            Jorts    Jimmy_lower                    0.2  15
# 12      Wife Beater      Mac_upper                    0.2   1
# 13       SP Booster      accessory                    0.2   0
# 14       HP Booster      accessory                    0.2   0
# 15   Damage Booster      accessory                    0.2   0
# 16   Brass Knuckles      accessory                      0   0
# 17   Gold Duck Tape      accessory                      0   0
# 18   Camo Duck Tape      accessory                      0   0
# 19  Sprinting Shoes      accessory                      0   0
# 20         Dio Band      accessory                      0  30
#
#                                                effect damagePlus maxSPPlus  \
# 0                                                none          0         0
# 1                                                none          0         0
# 2                                                none          0         0
# 3                                                none          0         0
# 4                                                none          0         0
# 5                                                none          0         0
# 6                                                none          0         0
# 7                                                none          0         0
# 8                                                none          0         0
# 9                                                none          0         0
# 10                                               none          0         0
# 11                                               none          0         0
# 12                                          Damage +5          5         0
# 13                                          Max SP +4          0         4
# 14                                         Max HP +20          0         0
# 15                              Damage +4, NEVER MISS          4         0
# 16                                         Damage +15         15         0
# 17                                  Prevents Bleeding          0         0
# 18                                 Prevents Blindness          0         0
# 19                       Athletics +.35\nFirst Strike          0         0
# 20  An Unholy Relic\nPrevents Bleeding\nPrevents B...         25         0
#
#    maxHPPlus neverMiss preventBleeding preventBlindness athletics firstStrike  \
# 0          0     false           false            false         0       false
# 1          0     false           false            false         0       false
# 2          0     false           false            false         0       false
# 3          0     false           false            false         0       false
# 4          0     false           false            false         0       false
# 5          0     false           false            false         0       false
# 6          0     false           false            false         0       false
# 7          0     false           false            false         0       false
# 8          0     false           false            false         0       false
# 9          0     false           false            false         0       false
# 10         0     false           false            false         0       false
# 11         0     false           false            false         0       false
# 12         0     false           false            false         0       false
# 13         0     false           false            false         0       false
# 14        20     false           false            false         0       false
# 15         0      true           false            false         0       false
# 16         0     false           false            false         0       false
# 17         0     false            true            false         0       false
# 18         0     false           false             true         0       false
# 19         0     false           false            false      0.35        true
# 20         0     false            true             true         0       false
#
#    numberOwned equipped character value
# 0            1        1       Mac     5
# 1            1        1       Mac     5
# 2            1        1     Jimmy     5
# 3            1        1     Jimmy     5
# 4            1        1        Al     5
# 5            1        1        Al     5
# 6            1        1   Bennett     5
# 7            1        1   Bennett     5
# 8            0        0       Mac    20
# 9            0        0       Mac    15
# 10           0        0        Al    30
# 11           0        0     Jimmy    10
# 12           0        0       Mac     5
# 13           0        0       all    20
# 14           0        0       all    20
# 15           0        0       all    20
# 16           0        0       all    30
# 17           0        0       all     5
# 18           0        0       all     5
# 19           0        0       all    50
# 20           0        0       all  1000

# %%
#saves the character-stats df in json format to 'data/json-files/inventory_items.json'
result = df.to_json(orient = "index")
parsed = json.loads(result)
jsonFilePath='data/json-files/equipment.json'
with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
    jsonf.write(json.dumps(parsed, indent=4))
print('saved to '+jsonFilePath)
# Out:
# saved to data/json-files/equipment.json
